# %%
import pandas as pd
import pickle
import json

# %%
df=pd.read_json("jsons/dblp_merge.json")

# %%
df
# Out:
#           index                                           abstract  \
# 0             0  The purpose of this study is to develop a lear...
# 1             1  This paper describes the design and implementa...
# 10           29  Spatial encryption is a generic public-key cry...
# 100         296  Game theory is concerned with optimization pro...
# 1000       2751  The field of interaction design encompasses a ...
# 10000     27310  The game description language (GDL), which is ...
# 100000   244311  In scientific workflow systems, temporal consi...
# 1000000  339363  This paper explores the use of innovative kern...
# 1000001  339365  In this paper, the behaviour of nonlinear dyna...
# 1000002  339366  Automatic, inexpensive, simple and sensitive m...
# 1000003  339367  Predicting the future direction of community e...
# 1000004  339368  Over the last few years, the quantity of telet...
# 1000005  339369  Compressive sensing based in-network compressi...
# ...

# %%
df=df[['authors','id','references']]

# %%
df
# Out:
#                                                    authors  \
# 0        [Makoto Satoh, Ryo Muramatsu, Mizue Kayama, Ka...
# 1                              [Gareth Beale, Graeme Earl]
# 10                         [Michel Abdalla, Jill-Jênn Vie]
# 100      [Francisco Gordillo, Ismael Alcalá, Javier Ara...
# 1000     [Michael Mose Biskjaer, Peter Dalsgaard, Kim H...
# 10000                                 [Michael Thielscher]
# 100000                   [Xiao Liu, Jinjun Chen, Yun Yang]
# 1000000  [Truc-Vien T. Nguyen, Alessandro Moschitti, Gi...
# 1000001  [Laurent Vanbeylen, Anne Van Mulders, Johan Sc...
# 1000002                [Haihong Chu, Jilin Yan, Yifeng Tu]
# 1000003  [Bogdan Gliwa, Piotr Bródka, Anna Zygmunt, Sta...
# 1000004  [Jongsuk Ruth Lee, Sang-Kug Ye, Hae-Duck Joshu...
# 1000005  [Xuangou Wu, Yan Xiong, Wenchao Huang, Hong Sh...
# 1000006  [Jan Christian Jarczyk, Ferdinand Svaricek, Be...
# 1000007    [Do-Sung Jun, Jinwoo Choe, Alberto Leon-Garcia]
# ...
