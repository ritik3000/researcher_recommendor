# %%
import pickle

# %%
s1=pickle.load(open("pickles/f1_org.pkl","rb"))

# %%
s2=pickle.load(open("pickles/venue_vector_score_mul.pkl","rb"))

# %%
s3=pickle.load(open("pickles/f1_percentage_collab_mul.pkl","rb"))

# %%
s4=pickle.load(open("pickles/f1_percentage_collab_add.pkl","rb"))

# %%
diff=0
for i in range(len(s1)):
    diff+=s2[i]-s1[i]

# %%
diff/120
# Out:
# -0.0039413417412010295

# %%
s1
# Out:
# array([0.        , 0.00377925, 0.00633016, 0.00912444, 0.01193625,
#        0.01450506, 0.01706649, 0.01992324, 0.02210835, 0.02387912,
#        0.02557887, 0.02757986, 0.02996004, 0.03174074, 0.03482929,
#        0.03663333, 0.038961  , 0.04079057, 0.04251388, 0.04492786,
#        0.0465438 , 0.04866906, 0.0503343 , 0.05215588, 0.05367272,
#        0.05512176, 0.05704024, 0.05849711, 0.06047977, 0.0622317 ,
#        0.06378041, 0.06534417, 0.06650956, 0.06741037, 0.06876136,
#        0.07054332, 0.07237961, 0.07373577, 0.07514196, 0.07645877,
#        0.07810101, 0.07902544, 0.08114482, 0.08246024, 0.08395431,
#        0.08548652, 0.08696203, 0.08834897, 0.09028393, 0.09201979,
#        0.09347606, 0.09471367, 0.09613504, 0.09784444, 0.09887003,
#        0.10022561, 0.10124096, 0.10260426, 0.10342623, 0.10423387,
#        0.10514129, 0.10618604, 0.10746161, 0.10863693, 0.10923586,
#        0.11029946, 0.11163722, 0.11304747, 0.11446907, 0.11589635,
# ...

# %%
s4
# Out:
# array([0.        , 0.00364224, 0.00684878, 0.00927663, 0.01239461,
#        0.01515049, 0.01752455, 0.02008072, 0.02259183, 0.02425162,
#        0.02639962, 0.02817946, 0.03035679, 0.0330695 , 0.03573383,
#        0.03752968, 0.03967797, 0.04137804, 0.04370091, 0.0454759 ,
#        0.04704848, 0.04880386, 0.05102096, 0.05283587, 0.0546794 ,
#        0.05673106, 0.05846294, 0.06024211, 0.06208952, 0.06377945,
#        0.06576979, 0.06682055, 0.06828163, 0.06963826, 0.0713458 ,
#        0.07323406, 0.07425198, 0.07609789, 0.07758066, 0.07899421,
#        0.08113653, 0.08235199, 0.08390136, 0.08502908, 0.086628  ,
#        0.08821096, 0.08961495, 0.09127781, 0.09226271, 0.09378479,
#        0.09544794, 0.09670554, 0.09858203, 0.09977568, 0.10111966,
#        0.10219561, 0.10371094, 0.10545456, 0.1063415 , 0.10775142,
#        0.10910029, 0.10960539, 0.11098069, 0.11165969, 0.11258167,
#        0.11354572, 0.11463888, 0.11613137, 0.11776125, 0.11927205,
# ...

# %%
s3
# Out:
# array([ 0.        ,  0.0031504 ,  0.00636204,  0.00951884,  0.01224872,
#         0.01476775,  0.01746767,  0.019572  ,  0.02222042,  0.02518344,
#         0.02806875,  0.02996466,  0.03150483,  0.03328214,  0.03571872,
#         0.03758852,  0.03972619,  0.04193062,  0.04364525,  0.04539539,
#         0.04699806,  0.04863173,  0.05060375,  0.05216299,  0.05427673,
#         0.05610904,  0.05817874,  0.05913747,  0.06060695,  0.06278945,
#         0.06402609,  0.06564187,  0.06720966,  0.06911631,  0.07040154,
#         0.07185686,  0.07388603,  0.07559663,  0.07681036,  0.07811419,
#         0.07989223,  0.08104758,  0.08277509,  0.08431738,  0.08519018,
#         0.08693469,  0.08837561,  0.08965199,  0.09104209,  0.09226749,
#         0.09303955,  0.09393367,  0.09544136,  0.09610581,  0.09778441,
#         0.09929441,  0.10098697,  0.10304321,  0.10379553,  0.10527937,
#         0.10594402,  0.10706818,  0.10814887,  0.10969966,  0.11077156,
# ...
